# %% [markdown]
# ### Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# - Matplotlib is a data visualization library in python.
# - It contains many features to visualize data including 3D visualizations.
# - It can generate various types of graphs.
# - In pyplot module of matplotlib we can create many types of graphs such as:
#     1. bar plot
#     2. line plot
#     3. scatter plot
#     4. histogram plot
#     5. pie plot

# %% [markdown]
# ### Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.

# %%
import numpy as np
np.random.seed(3)
x = 3+np.random.normal(0,2,50)
y = 3+np.random.normal(0,2,len(x))

# %% [markdown]
# #### Note: Also add title, xlabel, and ylabel to the plot.

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("Scatter Plot")
plt.show()

# %% [markdown]
# A scatter plot is nothing but dots marked at the respective coordinates.

# %% [markdown]
# ### Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# #### Use the following data:

# %% [markdown]
# ##### import numpy as np
# ##### For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# ##### For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# ##### For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# ##### For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# subplot() function is used for creating multiple plots.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x1 = np.array([0,1,2,3,4,5])
y1 = np.array([0,100,200,300,400,500])

x2 = np.array([0,1,2,3,4,5])
y2 = np.array([50,20,40,20,60,70])

x3 = np.array([0,1,2,3,4,5])
y3 = np.array([10,20,30,40,50,60])

x4 = np.array([0,1,2,3,4,5])
y4 = np.array([200,350,250,550,450,150])

fig, axs = plt.subplots(nrows=4, ncols=1)
plt.tight_layout()
axs[0].plot(x1,y1)
axs[1].plot(x2,y2)
axs[2].plot(x3,y3)
axs[3].plot(x4,y4)
plt.show()

# %% [markdown]
# ### Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# #### import numpy as np
# #### company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# #### profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# - A bar plot is a graph in which we can also plot categorical to numerical data.
# - Usually in the X-axis is the categorical and on Y-axis is the frequency or some numerical data.

# %%
import numpy as np

# %%
company = np.array(["Apple","Microsoft","Google","AMD"])
profit = np.array([3000,8000,1000,10000])

plt.bar(company,profit)
plt.xlabel("Company")
plt.ylabel("Profit")
plt.title("Bar Plot")
plt.show()

# %%
plt.barh(company,profit)
plt.ylabel("Company")
plt.xlabel("Profit")
plt.title("Horizontal Bar Plot")
plt.show()

# %% [markdown]
# ### Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# #### box1 = np.random.normal(100, 10, 200)
# #### box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# - A box plot is a graphical representation of a data set that summarizes its distribution. It shows the median, quartiles, and outliers of the data set.
# - Box plots are used to:
#     - Compare the distributions of two or more data sets.
#     - Identify outliers in a data set.
#     - Understand the shape of a data distribution.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

plt.boxplot([box1,box2])
plt.show()
